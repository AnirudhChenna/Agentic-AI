# %%
# in python variables are used to declare and assign values in them
age = 32
name="anirudh"
is_student=True
#printing the variables 
print("age:",age)
print("student:",is_student)
print("name:",name)
# Out:
# age: 32
# height: True
# name: anirudh

# %%
# naming conventions
# variable names should be descriptive
# they must start with a letter or an '_'and contains letter,numbers and underscores
# variable names are case sensitive
first_name="anirudh"
second_name="chenna"

# %%
# invalid variable names
2age=30
first-name="anirudh"
@name="anirudh"
# Out:
#   Cell In[5], line 2
#     2age=30
#     ^
# SyntaxError: invalid decimal literal

# %%
# case sensitivity in variables
name="anirudh"
Name="chenna"

# %%
# variable types
# python is dynamically typed,type of a variable is determined at runtime
age=25 #int
height =5.5 #float
is_student =True #boolean
name="anirudh" #str

# %%
# type conversion
age="25"
print(type(int(age)))
# Out:
# <class 'int'>

# %%
# dynamic typing 
var =10
print(var,type(var))
var="hello"
print(var,type(var))
var=3.14
print(var,type(var))
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 3.14 <class 'float'>

# %%
# input
age=int(input("whats your age"))
print(age,type(age))
# Out:
# 21 <class 'int'>

# %%
# simple calculator
